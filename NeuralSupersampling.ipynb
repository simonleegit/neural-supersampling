# %% [markdown]
# # Neural Supersampling

# %% [markdown]
# First of all, you should take a look at [SetupEnvironment.ipynb](./SetupEnvironment.ipynb)

# %% [markdown]
# ## Run unit tests

# %%
bash scripts/unittest.sh

# %% [markdown]
# ## Train model

# %%
bash scripts/train.sh

# %% [markdown]
# ## Evaluate

# %%
bash scripts/evaluate.sh

# %% [markdown]
# ## Visualize

# %%
bash scripts/visualize.sh

# %% [markdown]
# Run below to show output vedio in notebook.

# %%
import os
from IPython.display import HTML
from base64 import b64encode
with open(os.environ["VIDEO_OUTPUT"], "rb") as video:
    data_url = "data:video/mp4;base64," + b64encode(video.read()).decode()
HTML(f"""
    <video width="720" controls>
        <source src="{data_url}" type="video/mp4">
    </video>
""")
