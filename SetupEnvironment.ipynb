# %% [markdown]
# # Setup Envirnoment

# %% [markdown]
# ## Clone repository

# %%
git clone https://github.com/SimonLeeGit/neural-supersampling.git
cd neural-supersampling

# %% [markdown]
# ## Build Development Docker Image
#
# For better development experience, I use docker as my develop environment.
#
# If you new to docker, please follow the [docker install](https://docs.nvidia.com/datacenter/cloud-native/container-toolkit/latest/install-guide.html)
#
# I use the base docker image from [nvidia docker hub](https://docs.nvidia.com/deeplearning/frameworks/pytorch-release-notes/rel-24-01.html), here I'm using the 23.12 for me, you can change it by [Dockerfile](./docker/Dockerfile.base).

# %%
bash scripts/build_docker.sh

# %% [markdown]
# ## Run Development Docker Container with Interactive

# %%
bash scripts/run_docker.sh

# %% [markdown]
# Now, you should enter the running docker container.
#
# Then, you can continue using [NeuralSupersampling.ipynb](./NeuralSupersampling.ipynb) for training and testing.
